# %% [markdown]
# <a href="https://colab.research.google.com/github/wsj20010128/ML_Notes/blob/main/Linear-Regression/01-Simple-Linear-Regression/01-Simple-Linear-Regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Implement Simple Linear Regression

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.array([1., 2., 3., 4., 5.])
y = np.array([1., 3., 2., 3., 5.])

# %%
plt.scatter(x, y)
plt.axis([0, 6, 0, 6])
plt.show()

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
x_mean = np.mean(x)
y_mean = np.mean(y)

# %%
num = 0.0
d = 0.0
for x_i, y_i in zip(x, y):
  num += (x_i - x_mean) * (y_i - y_mean)
  d += (x_i - x_mean) ** 2

# %%
a = num / d
b = y_mean - a * x_mean

# %%
a
# Out:
# 0.8

# %%
b
# Out:
# 0.39999999999999947

# %%
y_hat = a * x + b

# %%
plt.scatter(x, y)
plt.plot(x, y_hat, color='r')
plt.axis([0, 6, 0, 6])
plt.show()

# %%
x_predict = 6
y_predict = a * x_predict + b

# %%
y_predict
# Out:
# 5.2

# %% [markdown]
# ## Use my own SimpleLinearRegression

# %%
from SimpleLinearRegression import SimpleLinearRegression1

reg1 = SimpleLinearRegression1()
reg1.fit(x, y)
# Out:
# SimpleLinearRegression1()

# %%
reg1.predict(np.array([x_predict]))
# Out:
# array([5.2])

# %%
reg1.a_
# Out:
# 0.8

# %%
reg1.b_
# Out:
# 0.39999999999999947

# %%
y_hat1 = reg1.predict(x)

# %%
plt.scatter(x, y)
plt.plot(x, y_hat1, color='r')
plt.axis([0, 6, 0, 6])
plt.show()
